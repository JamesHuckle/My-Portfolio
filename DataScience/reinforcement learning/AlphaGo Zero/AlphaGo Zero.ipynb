# %% [markdown]
# # AlphaGo Zero for connect 2

# %% [markdown]
# https://web.stanford.edu/~surag/posts/alphazero.html <br>
# https://www.youtube.com/watch?v=62nq4Zsn8vc&ab_channel=JoshVarty <br>

# %% [markdown]
# ### Value network and self play
# 1) Play a bunch of games against yourself and record whether a given board state eventually lead to a win or a loss. We take a snapshot of what the board looks like when presented to each player and want to determine how good of a position they are currently in before they take a move. <br>
#
# `
#  BOARD STATE
# [ 0  0  0  0] # Start of the game, presented to Player 1. Player 1 plays in the first position.
# [-1  0  0  0] # Player 2 is presented with this board. Player 2 plays in the third position.
# [ 1  0 -1  0] # Player 1 is presented with this board. Player 1 plays in the second position
# [-1 -1  1  0] # Player 2 is presented with this board. Player 2 was lost as Player 1 can connect 2
# `
#
# 2) Create a labelled training set for the value NN by going back through all of the game states held by Player 1 and marking them with a reward of 1. Similarily go through all of the states held by Player 2 and mark them with a reward of -1. <br>
# `
#   BOARD STATE   RES
# ([ 0  0  0  0], 1) # Player 1
# ([-1  0  0  0],-1) # Player 2
# ([ 1  0 -1  0], 1) # Player 1
# ([-1 -1  1  0],-1) # Player 2
# `
#
# 3) After completing thousands of self play games, we shuffle up the board training data and feed it into our neural network to train it to recognise what the probability of winning is given a particular board state. The output will be from -1 to 1. This is essentially an image recognition task, which is why AlphaGo uses resnets.
#
# <img src="value_network.PNG" alt="drawing" width="400"/>
#
#
# ### Policy Network
# Takes a game state / board as input and outputs next move a probability distribution of next moves, with move with the highest probability being the move which the policy network thinks will do the best.
#
# <img src="policy_network.PNG" alt="drawing" width="400"/>
#
# Based upon the output above, we will win 88% of the time if you make a move into the first position and have a 10% probability of winning in the last position. Wierdly, it outputs a non-zero chance of winning if we take invalid moves where there are already pieces. This is because we cannot control the NN to output 0 values for invalid moves. Instead, we will have to write code to mask out invalid moves and redistribute the values.
#
# The way we train the network is to actually encourage it to give the same output an Monte Carlo Tree search (more on that later). To do this we create a dataset that includes a board state, and also what the MCTS suggested we do at that position.
# `
# BOARD STATE             MCTS
# ([ 0  0  0  0], [0.1, 0.4, 0.4, 0.1])
# ([-1  0  0  0], [0.0, 0.3, 0.3, 0.3])
# ([ 1  0 -1  0], [0.0, 0.8, 0.0, 0.2])
# `
#
# There is actually an interesting circular dependency, where by we are training our policy network to output results that match the MCTS, but we actually use our policy to network to choose the most promising next positions to expolore with MCTS. In theory, improving the policy network will improve the MCTS and visa versa.
#
#
# ### AlphaGo Zero actually uses the same network to output the policy and value
#
# <img src="policy_value.PNG" alt="drawing" width="400"/>
#
# ### MCTS
# Normally MCTS would entail doing rollouts until the a particular game is ran to conclusion and then the result is backed up to update the previous states; however, with AlphaGo Zero we actually use the results from the value network to score each state. Of course, if we do happen to reach a terminal game state, then the actual result will be used instead and backed up. The lack of focus of complete rollouts can be hugely befefitial in a game like Go where there are any moves until termination.

# %%
import torch

from game import Connect2Game
from model import Connect2Model
from trainer import Trainer

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

args = {
    'batch_size': 64,
    'num_simulations': 100,                 # Number of Monte Carlo simulations for each move
    'numIters': 500,                        # Total number of training iterations
    'numEps': 100,                          # Number of full games (episodes) to run during each iteration
    'numItersForTrainExamplesHistory': 20,
    'epochs': 2,                            # Number of epochs of training per iteration
    'checkpoint_path': 'latest.pth'         # location to save latest set of weights
}

game = Connect2Game()
board_size = game.get_board_size()
action_size = game.get_action_size()

model = Connect2Model(board_size, action_size, device)

trainer = Trainer(game, model, args)
trainer.learn()
# Out:
# 1/500
#
# Policy Loss 1.4157464504241943
# Value Loss 0.8966259807348251
# Examples:
# tensor([0.2723, 0.2117, 0.2783, 0.2376], device='cuda:0')
# tensor([0.0400, 0.0100, 0.9300, 0.0200], device='cuda:0')
#
# Policy Loss 1.4188497811555862
# Value Loss 0.8844451904296875
# Examples:
# tensor([0.2717, 0.2126, 0.2786, 0.2370], device='cuda:0')
# tensor([0.0400, 0.0100, 0.9300, 0.0200], device='cuda:0')
# 2/500
#
# Policy Loss 1.4166783094406128
# Value Loss 0.871482715010643
# Examples:
# tensor([0.2666, 0.2081, 0.2799, 0.2454], device='cuda:0')
# tensor([0.2600, 0.3400, 0.0000, 0.4000], device='cuda:0')
#
# Policy Loss 1.411540761590004
# Value Loss 0.8693072274327278
# Examples:
# tensor([0.2656, 0.2087, 0.2807, 0.2450], device='cuda:0')
# tensor([0.2600, 0.3400, 0.0000, 0.4000], device='cuda:0')
# 3/500
#
# Policy Loss 1.4092235565185547
# Value Loss 0.8500819355249405
# Examples:
# tensor([0.2764, 0.2219, 0.2709, 0.2309], device='cuda:0')
# tensor([0.0500, 0.9500, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 1.404719591140747
# Value Loss 0.8532554432749748
# Examples:
# tensor([0.2686, 0.2162, 0.2806, 0.2346], device='cuda:0')
# tensor([0.0200, 0.0100, 0.9500, 0.0200], device='cuda:0')
# 4/500
#
# Policy Loss 1.3959605991840363
# Value Loss 0.8214873820543289
# Examples:
# tensor([0.2622, 0.2101, 0.2842, 0.2435], device='cuda:0')
# tensor([0.2700, 0.3600, 0.0000, 0.3700], device='cuda:0')
#
# Policy Loss 1.3973059803247452
# Value Loss 0.8299559503793716
# Examples:
# tensor([0.2611, 0.2105, 0.2853, 0.2431], device='cuda:0')
# tensor([0.2700, 0.3600, 0.0000, 0.3700], device='cuda:0')
# 5/500
#
# Policy Loss 1.397823989391327
# Value Loss 0.8464534878730774
# Examples:
# tensor([0.2658, 0.2186, 0.2831, 0.2325], device='cuda:0')
# tensor([0.0200, 0.0100, 0.9500, 0.0200], device='cuda:0')
#
# Policy Loss 1.3945499956607819
# Value Loss 0.8200047686696053
# Examples:
# tensor([0.2590, 0.2117, 0.2870, 0.2423], device='cuda:0')
# tensor([0.2700, 0.3600, 0.0000, 0.3700], device='cuda:0')
# 6/500
#
# Policy Loss 1.392373651266098
# Value Loss 0.8084501177072525
# Examples:
# tensor([0.2580, 0.2122, 0.2879, 0.2419], device='cuda:0')
# tensor([0.2700, 0.3600, 0.0000, 0.3700], device='cuda:0')
#
# Policy Loss 1.3898454010486603
# Value Loss 0.8044463247060776
# Examples:
# tensor([0.2630, 0.2214, 0.2850, 0.2305], device='cuda:0')
# tensor([0.0200, 0.0100, 0.9500, 0.0200], device='cuda:0')
# 7/500
#
# Policy Loss 1.384826511144638
# Value Loss 0.815926194190979
# Examples:
# tensor([0.2561, 0.2137, 0.2888, 0.2414], device='cuda:0')
# tensor([0.2700, 0.3600, 0.0000, 0.3700], device='cuda:0')
#
# Policy Loss 1.3872821927070618
# Value Loss 0.7838451042771339
# Examples:
# tensor([0.2553, 0.2144, 0.2892, 0.2412], device='cuda:0')
# tensor([0.2700, 0.3600, 0.0000, 0.3700], device='cuda:0')
# 8/500
#
# Policy Loss 1.3784427642822266
# Value Loss 0.7616879642009735
# Examples:
# tensor([0.2544, 0.2149, 0.2896, 0.2411], device='cuda:0')
# tensor([0.2700, 0.3600, 0.0000, 0.3700], device='cuda:0')
#
# Policy Loss 1.3785704374313354
# Value Loss 0.7535334601998329
# Examples:
# tensor([0.2596, 0.2249, 0.2876, 0.2279], device='cuda:0')
# tensor([0.0200, 0.0200, 0.9500, 0.0100], device='cuda:0')
# 9/500
#
# Policy Loss 1.3713909983634949
# Value Loss 0.7360422313213348
# Examples:
# tensor([0.2686, 0.2432, 0.2693, 0.2188], device='cuda:0')
# tensor([0.0400, 0.9600, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 1.3766966462135315
# Value Loss 0.7273747771978378
# Examples:
# tensor([0.2678, 0.2455, 0.2690, 0.2178], device='cuda:0')
# tensor([0.0400, 0.9600, 0.0000, 0.0000], device='cuda:0')
# 10/500
#
# Policy Loss 1.3762758076190948
# Value Loss 0.8235275894403458
# Examples:
# tensor([0.2395, 0.2224, 0.2993, 0.2388], device='cuda:0')
# tensor([0.0400, 0.0000, 0.0000, 0.9600], device='cuda:0')
#
# Policy Loss 1.3761166036128998
# Value Loss 0.8189966380596161
# Examples:
# tensor([0.2495, 0.2152, 0.2918, 0.2435], device='cuda:0')
# tensor([0.2600, 0.3700, 0.0000, 0.3700], device='cuda:0')
# 11/500
#
# Policy Loss 1.3784857392311096
# Value Loss 0.8078736513853073
# Examples:
# tensor([0.2551, 0.2243, 0.2911, 0.2295], device='cuda:0')
# tensor([0.0200, 0.0100, 0.9600, 0.0100], device='cuda:0')
#
# Policy Loss 1.3711451888084412
# Value Loss 0.8016822412610054
# Examples:
# tensor([0.2542, 0.2235, 0.2916, 0.2307], device='cuda:0')
# tensor([0.0200, 0.0100, 0.9600, 0.0100], device='cuda:0')
# 12/500
#
# Policy Loss 1.3544417023658752
# Value Loss 0.7007236778736115
# Examples:
# tensor([0.2533, 0.2240, 0.2924, 0.2304], device='cuda:0')
# tensor([0.0200, 0.0100, 0.9600, 0.0100], device='cuda:0')
#
# Policy Loss 1.360081598162651
# Value Loss 0.6946987062692642
# Examples:
# tensor([0.2615, 0.2469, 0.2713, 0.2202], device='cuda:0')
# tensor([0.0400, 0.9600, 0.0000, 0.0000], device='cuda:0')
# 13/500
#
# Policy Loss 1.3552129566669464
# Value Loss 0.6967796683311462
# Examples:
# tensor([0.2509, 0.2258, 0.2946, 0.2288], device='cuda:0')
# tensor([0.0200, 0.0100, 0.9600, 0.0100], device='cuda:0')
#
# Policy Loss 1.3538772016763687
# Value Loss 0.6824495866894722
# Examples:
# tensor([0.2496, 0.2267, 0.2957, 0.2280], device='cuda:0')
# tensor([0.0200, 0.0100, 0.9600, 0.0100], device='cuda:0')
# 14/500
#
# Policy Loss 1.3534573018550873
# Value Loss 0.6669950783252716
# Examples:
# tensor([0.2582, 0.2545, 0.2711, 0.2162], device='cuda:0')
# tensor([0.0400, 0.9600, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 1.35061876475811
# Value Loss 0.6676511391997337
# Examples:
# tensor([0.2469, 0.2286, 0.2975, 0.2269], device='cuda:0')
# tensor([0.0200, 0.0100, 0.9600, 0.0100], device='cuda:0')
# 15/500
#
# Policy Loss 1.3526954054832458
# Value Loss 0.6873549371957779
# Examples:
# tensor([0.2454, 0.2295, 0.2987, 0.2264], device='cuda:0')
# tensor([0.0200, 0.0100, 0.9600, 0.0100], device='cuda:0')
#
# Policy Loss 1.3446397185325623
# Value Loss 0.6692834943532944
# Examples:
# tensor([0.2544, 0.2627, 0.2708, 0.2121], device='cuda:0')
# tensor([0.0400, 0.9600, 0.0000, 0.0000], device='cuda:0')
# 16/500
#
# Policy Loss 1.3344760537147522
# Value Loss 0.6185261011123657
# Examples:
# tensor([0.2426, 0.2314, 0.3009, 0.2251], device='cuda:0')
# tensor([0.0200, 0.0100, 0.9600, 0.0100], device='cuda:0')
#
# Policy Loss 1.329190343618393
# Value Loss 0.6214520186185837
# Examples:
# tensor([0.2518, 0.2684, 0.2705, 0.2093], device='cuda:0')
# tensor([0.0400, 0.9600, 0.0000, 0.0000], device='cuda:0')
# 17/500
#
# Policy Loss 1.3261966109275818
# Value Loss 0.6275336742401123
# Examples:
# tensor([0.2503, 0.2713, 0.2706, 0.2077], device='cuda:0')
# tensor([0.0400, 0.9600, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 1.3230769634246826
# Value Loss 0.621587760746479
# Examples:
# tensor([0.2489, 0.2744, 0.2705, 0.2062], device='cuda:0')
# tensor([0.0400, 0.9600, 0.0000, 0.0000], device='cuda:0')
# 18/500
#
# Policy Loss 1.3143889605998993
# Value Loss 0.5788149684667587
# Examples:
# tensor([0.2292, 0.2208, 0.3004, 0.2496], device='cuda:0')
# tensor([0.2500, 0.3700, 0.0000, 0.3800], device='cuda:0')
#
# Policy Loss 1.3083192259073257
# Value Loss 0.5647684782743454
# Examples:
# tensor([0.2461, 0.2812, 0.2693, 0.2033], device='cuda:0')
# tensor([0.0400, 0.9600, 0.0000, 0.0000], device='cuda:0')
# 19/500
#
# Policy Loss 1.3037468194961548
# Value Loss 0.5636889785528183
# Examples:
# tensor([0.2260, 0.2218, 0.3020, 0.2502], device='cuda:0')
# tensor([0.2500, 0.3700, 0.0000, 0.3800], device='cuda:0')
#
# Policy Loss 1.304384484887123
# Value Loss 0.5504623055458069
# Examples:
# tensor([0.2323, 0.2387, 0.3090, 0.2199], device='cuda:0')
# tensor([0.0200, 0.0100, 0.9600, 0.0100], device='cuda:0')
# 20/500
#
# Policy Loss 1.2840705811977386
# Value Loss 0.5555926710367203
# Examples:
# tensor([0.2227, 0.2229, 0.3033, 0.2511], device='cuda:0')
# tensor([0.2500, 0.3700, 0.0000, 0.3800], device='cuda:0')
#
# Policy Loss 1.2810958474874496
# Value Loss 0.5453980788588524
# Examples:
# tensor([0.2290, 0.2408, 0.3123, 0.2179], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 21/500
#
# Policy Loss 1.3760843575000763
# Value Loss 0.6301158368587494
# Examples:
# tensor([0.2196, 0.2230, 0.3043, 0.2531], device='cuda:0')
# tensor([0.2400, 0.3800, 0.0000, 0.3800], device='cuda:0')
#
# Policy Loss 1.3638264536857605
# Value Loss 0.6182714700698853
# Examples:
# tensor([0.2184, 0.2221, 0.3039, 0.2555], device='cuda:0')
# tensor([0.2400, 0.3800, 0.0000, 0.3800], device='cuda:0')
# 22/500
#
# Policy Loss 1.2837407886981964
# Value Loss 0.4967113807797432
# Examples:
# tensor([0.2169, 0.2224, 0.3046, 0.2562], device='cuda:0')
# tensor([0.2400, 0.3700, 0.0000, 0.3900], device='cuda:0')
#
# Policy Loss 1.2755832523107529
# Value Loss 0.4786642976105213
# Examples:
# tensor([0.2329, 0.3019, 0.2686, 0.1966], device='cuda:0')
# tensor([0.0400, 0.9600, 0.0000, 0.0000], device='cuda:0')
# 23/500
#
# Policy Loss 1.2757640182971954
# Value Loss 0.4857849106192589
# Examples:
# tensor([0.2135, 0.2235, 0.3059, 0.2571], device='cuda:0')
# tensor([0.2400, 0.3700, 0.0000, 0.3900], device='cuda:0')
#
# Policy Loss 1.2745856046676636
# Value Loss 0.4816209636628628
# Examples:
# tensor([0.2282, 0.3114, 0.2674, 0.1930], device='cuda:0')
# tensor([0.0400, 0.9600, 0.0000, 0.0000], device='cuda:0')
# 24/500
#
# Policy Loss 1.275465726852417
# Value Loss 0.4746265709400177
# Examples:
# tensor([0.2260, 0.3167, 0.2661, 0.1913], device='cuda:0')
# tensor([0.0400, 0.9600, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 1.2649015486240387
# Value Loss 0.46696967631578445
# Examples:
# tensor([0.2236, 0.3219, 0.2650, 0.1895], device='cuda:0')
# tensor([0.0400, 0.9600, 0.0000, 0.0000], device='cuda:0')
# 25/500
#
# Policy Loss 1.2398620545864105
# Value Loss 0.43181315809488297
# Examples:
# tensor([0.2210, 0.3273, 0.2638, 0.1878], device='cuda:0')
# tensor([0.0400, 0.9600, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 1.240654170513153
# Value Loss 0.4368695355951786
# Examples:
# tensor([0.2138, 0.2503, 0.3218, 0.2141], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 26/500
#
# Policy Loss 1.2265547513961792
# Value Loss 0.39828136563301086
# Examples:
# tensor([0.2039, 0.2278, 0.3061, 0.2621], device='cuda:0')
# tensor([0.2300, 0.3800, 0.0000, 0.3900], device='cuda:0')
#
# Policy Loss 1.2194741517305374
# Value Loss 0.39714154973626137
# Examples:
# tensor([0.2024, 0.2286, 0.3060, 0.2630], device='cuda:0')
# tensor([0.2300, 0.3800, 0.0000, 0.3900], device='cuda:0')
# 27/500
#
# Policy Loss 1.2119472026824951
# Value Loss 0.4072427526116371
# Examples:
# tensor([0.2099, 0.3493, 0.2611, 0.1797], device='cuda:0')
# tensor([0.0300, 0.9700, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 1.2094916105270386
# Value Loss 0.3895077258348465
# Examples:
# tensor([0.2068, 0.2570, 0.3260, 0.2102], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 28/500
#
# Policy Loss 1.205603927373886
# Value Loss 0.38181015104055405
# Examples:
# tensor([0.2051, 0.2588, 0.3269, 0.2093], device='cuda:0')
# tensor([0.0100, 0.0200, 0.9600, 0.0100], device='cuda:0')
#
# Policy Loss 1.2005966007709503
# Value Loss 0.37541133165359497
# Examples:
# tensor([0.2035, 0.2607, 0.3274, 0.2085], device='cuda:0')
# tensor([0.0100, 0.0200, 0.9600, 0.0100], device='cuda:0')
# 29/500
#
# Policy Loss 1.2021482288837433
# Value Loss 0.3829093351960182
# Examples:
# tensor([0.1940, 0.2322, 0.3072, 0.2666], device='cuda:0')
# tensor([0.2200, 0.3800, 0.0000, 0.4000], device='cuda:0')
#
# Policy Loss 1.1930178105831146
# Value Loss 0.3728184849023819
# Examples:
# tensor([0.1923, 0.2330, 0.3073, 0.2674], device='cuda:0')
# tensor([0.2200, 0.3800, 0.0000, 0.4000], device='cuda:0')
# 30/500
#
# Policy Loss 1.1907042562961578
# Value Loss 0.3675049841403961
# Examples:
# tensor([0.1906, 0.2337, 0.3076, 0.2681], device='cuda:0')
# tensor([0.2200, 0.3800, 0.0000, 0.4000], device='cuda:0')
#
# Policy Loss 1.1857142895460129
# Value Loss 0.3565673567354679
# Examples:
# tensor([0.1957, 0.2674, 0.3332, 0.2038], device='cuda:0')
# tensor([0.0100, 0.0200, 0.9600, 0.0100], device='cuda:0')
# 31/500
#
# Policy Loss 1.3886314928531647
# Value Loss 0.3878590986132622
# Examples:
# tensor([0.1707, 0.2937, 0.3315, 0.2040], device='cuda:0')
# tensor([0.0400, 0.0000, 0.0000, 0.9600], device='cuda:0')
#
# Policy Loss 1.383117601275444
# Value Loss 0.3830947242677212
# Examples:
# tensor([0.1693, 0.2931, 0.3316, 0.2060], device='cuda:0')
# tensor([0.0400, 0.0000, 0.0000, 0.9600], device='cuda:0')
# 32/500
#
# Policy Loss 1.1393417716026306
# Value Loss 0.3011794835329056
# Examples:
# tensor([0.1913, 0.2681, 0.3353, 0.2054], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 1.1398234963417053
# Value Loss 0.3026334196329117
# Examples:
# tensor([0.1832, 0.2369, 0.3043, 0.2756], device='cuda:0')
# tensor([0.2100, 0.3800, 0.0000, 0.4100], device='cuda:0')
# 33/500
#
# Policy Loss 1.374086856842041
# Value Loss 0.35439691692590714
# Examples:
# tensor([0.1819, 0.2372, 0.3028, 0.2781], device='cuda:0')
# tensor([0.2100, 0.4400, 0.0000, 0.3500], device='cuda:0')
#
# Policy Loss 1.3843193799257278
# Value Loss 0.34281206130981445
# Examples:
# tensor([0.1866, 0.2693, 0.3378, 0.2062], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 34/500
#
# Policy Loss 1.3646753132343292
# Value Loss 0.33120520412921906
# Examples:
# tensor([0.1605, 0.2981, 0.3338, 0.2076], device='cuda:0')
# tensor([0.0400, 0.0000, 0.0000, 0.9600], device='cuda:0')
#
# Policy Loss 1.3686283975839615
# Value Loss 0.32203184440732
# Examples:
# tensor([0.1840, 0.2674, 0.3391, 0.2095], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 35/500
#
# Policy Loss 1.1670301258563995
# Value Loss 0.2828438803553581
# Examples:
# tensor([0.1773, 0.2371, 0.2959, 0.2897], device='cuda:0')
# tensor([0.2000, 0.3900, 0.0000, 0.4100], device='cuda:0')
#
# Policy Loss 1.1588962227106094
# Value Loss 0.2686374709010124
# Examples:
# tensor([0.1759, 0.2387, 0.2947, 0.2907], device='cuda:0')
# tensor([0.2000, 0.3900, 0.0000, 0.4100], device='cuda:0')
# 36/500
#
# Policy Loss 1.3811790943145752
# Value Loss 0.2895333915948868
# Examples:
# tensor([0.1795, 0.2714, 0.3396, 0.2095], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 1.3733332455158234
# Value Loss 0.2876889854669571
# Examples:
# tensor([0.1519, 0.3045, 0.3329, 0.2107], device='cuda:0')
# tensor([0.0400, 0.0000, 0.0000, 0.9600], device='cuda:0')
# 37/500
#
# Policy Loss 1.3343274295330048
# Value Loss 0.28513067960739136
# Examples:
# tensor([0.1724, 0.2380, 0.2886, 0.3011], device='cuda:0')
# tensor([0.2000, 0.4000, 0.0000, 0.4000], device='cuda:0')
#
# Policy Loss 1.3390192091464996
# Value Loss 0.2721592504531145
# Examples:
# tensor([0.1712, 0.2376, 0.2865, 0.3047], device='cuda:0')
# tensor([0.2000, 0.4000, 0.0000, 0.4000], device='cuda:0')
# 38/500
#
# Policy Loss 1.134196400642395
# Value Loss 0.23059940338134766
# Examples:
# tensor([0.1732, 0.2696, 0.3436, 0.2136], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 1.134470745921135
# Value Loss 0.22448247112333775
# Examples:
# tensor([0.1684, 0.2407, 0.2842, 0.3068], device='cuda:0')
# tensor([0.1900, 0.3900, 0.0000, 0.4200], device='cuda:0')
# 39/500
#
# Policy Loss 1.359488070011139
# Value Loss 0.2332305684685707
# Examples:
# tensor([0.1420, 0.3086, 0.3364, 0.2130], device='cuda:0')
# tensor([0.0400, 0.0000, 0.0000, 0.9600], device='cuda:0')
#
# Policy Loss 1.3575872480869293
# Value Loss 0.22835743241012096
# Examples:
# tensor([0.1659, 0.2402, 0.2804, 0.3135], device='cuda:0')
# tensor([0.2000, 0.4100, 0.0000, 0.3900], device='cuda:0')
# 40/500
#
# Policy Loss 1.124553143978119
# Value Loss 0.2081933468580246
# Examples:
# tensor([0.1643, 0.2417, 0.2794, 0.3145], device='cuda:0')
# tensor([0.1900, 0.4000, 0.0000, 0.4100], device='cuda:0')
#
# Policy Loss 1.1161326617002487
# Value Loss 0.20293920300900936
# Examples:
# tensor([0.1647, 0.2750, 0.3483, 0.2120], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 41/500
#
# Policy Loss 1.3406972885131836
# Value Loss 0.19730279222130775
# Examples:
# tensor([0.1631, 0.2748, 0.3490, 0.2130], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 1.3294877111911774
# Value Loss 0.19949735328555107
# Examples:
# tensor([0.1324, 0.3100, 0.3411, 0.2166], device='cuda:0')
# tensor([0.0400, 0.0000, 0.0000, 0.9600], device='cuda:0')
# 42/500
#
# Policy Loss 1.1181742250919342
# Value Loss 0.18003155663609505
# Examples:
# tensor([0.1346, 0.4323, 0.2617, 0.1714], device='cuda:0')
# tensor([0.0200, 0.9800, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 1.1032101064920425
# Value Loss 0.17319556325674057
# Examples:
# tensor([0.1575, 0.2464, 0.2727, 0.3234], device='cuda:0')
# tensor([0.1900, 0.4000, 0.0000, 0.4100], device='cuda:0')
# 43/500
#
# Policy Loss 1.357784241437912
# Value Loss 0.17171531915664673
# Examples:
# tensor([0.1564, 0.2774, 0.3530, 0.2132], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 1.3419467955827713
# Value Loss 0.17049757950007915
# Examples:
# tensor([0.1553, 0.2762, 0.3526, 0.2159], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 44/500
#
# Policy Loss 1.0835772156715393
# Value Loss 0.13969111070036888
# Examples:
# tensor([0.1538, 0.2475, 0.2658, 0.3329], device='cuda:0')
# tensor([0.1800, 0.4000, 0.0000, 0.4200], device='cuda:0')
#
# Policy Loss 1.0874934494495392
# Value Loss 0.13948346488177776
# Examples:
# tensor([0.1525, 0.2499, 0.2632, 0.3344], device='cuda:0')
# tensor([0.1800, 0.4000, 0.0000, 0.4200], device='cuda:0')
# 45/500
#
# Policy Loss 1.3262956142425537
# Value Loss 0.14889003708958626
# Examples:
# tensor([0.1200, 0.3230, 0.3406, 0.2163], device='cuda:0')
# tensor([0.0400, 0.0000, 0.0000, 0.9600], device='cuda:0')
#
# Policy Loss 1.323670208454132
# Value Loss 0.14345251396298409
# Examples:
# tensor([0.1500, 0.2498, 0.2574, 0.3427], device='cuda:0')
# tensor([0.1800, 0.4100, 0.0000, 0.4100], device='cuda:0')
# 46/500
#
# Policy Loss 1.0784142911434174
# Value Loss 0.1206500343978405
# Examples:
# tensor([0.1188, 0.4537, 0.2540, 0.1734], device='cuda:0')
# tensor([0.0200, 0.9800, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 1.07403364777565
# Value Loss 0.12329933606088161
# Examples:
# tensor([0.1160, 0.4631, 0.2512, 0.1697], device='cuda:0')
# tensor([0.0200, 0.9800, 0.0000, 0.0000], device='cuda:0')
# 47/500
#
# Policy Loss 1.0755214393138885
# Value Loss 0.11415063962340355
# Examples:
# tensor([0.1444, 0.2896, 0.3535, 0.2125], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 1.0595181435346603
# Value Loss 0.11236033868044615
# Examples:
# tensor([0.1426, 0.2932, 0.3536, 0.2105], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 48/500
#
# Policy Loss 1.3188742697238922
# Value Loss 0.11448235437273979
# Examples:
# tensor([0.1414, 0.2926, 0.3540, 0.2120], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 1.3140589743852615
# Value Loss 0.11199944466352463
# Examples:
# tensor([0.1400, 0.2904, 0.3556, 0.2140], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 49/500
#
# Policy Loss 1.0373052060604095
# Value Loss 0.0912480317056179
# Examples:
# tensor([0.1385, 0.2934, 0.3549, 0.2132], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 1.029490977525711
# Value Loss 0.09039907902479172
# Examples:
# tensor([0.1030, 0.4934, 0.2407, 0.1629], device='cuda:0')
# tensor([0.0200, 0.9800, 0.0000, 0.0000], device='cuda:0')
# 50/500
#
# Policy Loss 1.302404135465622
# Value Loss 0.09659232012927532
# Examples:
# tensor([0.1380, 0.2634, 0.2355, 0.3630], device='cuda:0')
# tensor([0.1600, 0.4300, 0.0000, 0.4100], device='cuda:0')
#
# Policy Loss 1.3040055334568024
# Value Loss 0.09325658343732357
# Examples:
# tensor([0.1367, 0.2629, 0.2327, 0.3677], device='cuda:0')
# tensor([0.1600, 0.4300, 0.0000, 0.4100], device='cuda:0')
# 51/500
#
# Policy Loss 1.3094049096107483
# Value Loss 0.0845458023250103
# Examples:
# tensor([0.1014, 0.3344, 0.3414, 0.2227], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
#
# Policy Loss 1.2885963469743729
# Value Loss 0.08670801483094692
# Examples:
# tensor([0.1320, 0.2884, 0.3601, 0.2195], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 52/500
#
# Policy Loss 1.0472074151039124
# Value Loss 0.07764223217964172
# Examples:
# tensor([0.1304, 0.2909, 0.3599, 0.2188], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 1.0368241369724274
# Value Loss 0.07576971128582954
# Examples:
# tensor([0.1313, 0.2662, 0.2217, 0.3808], device='cuda:0')
# tensor([0.1500, 0.4200, 0.0000, 0.4300], device='cuda:0')
# 53/500
#
# Policy Loss 1.0194902420043945
# Value Loss 0.06812278926372528
# Examples:
# tensor([0.1267, 0.2979, 0.3611, 0.2142], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 1.0156041830778122
# Value Loss 0.0670166788622737
# Examples:
# tensor([0.1249, 0.3014, 0.3618, 0.2119], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 54/500
#
# Policy Loss 0.9909578859806061
# Value Loss 0.06024184077978134
# Examples:
# tensor([0.0870, 0.5182, 0.2353, 0.1594], device='cuda:0')
# tensor([0.0200, 0.9800, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.9855852276086807
# Value Loss 0.05916796298697591
# Examples:
# tensor([0.1212, 0.3080, 0.3636, 0.2072], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 55/500
#
# Policy Loss 1.2919872105121613
# Value Loss 0.059097773395478725
# Examples:
# tensor([0.1202, 0.3065, 0.3645, 0.2089], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 1.2920629680156708
# Value Loss 0.05723779834806919
# Examples:
# tensor([0.0873, 0.3562, 0.3419, 0.2146], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
# 56/500
#
# Policy Loss 0.9954492896795273
# Value Loss 0.05310396570712328
# Examples:
# tensor([0.0812, 0.5217, 0.2367, 0.1604], device='cuda:0')
# tensor([0.0200, 0.9800, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.9913587868213654
# Value Loss 0.05257585132494569
# Examples:
# tensor([0.1200, 0.2797, 0.2037, 0.3966], device='cuda:0')
# tensor([0.1400, 0.4200, 0.0000, 0.4400], device='cuda:0')
# 57/500
#
# Policy Loss 0.9623112827539444
# Value Loss 0.047828176990151405
# Examples:
# tensor([0.0758, 0.5422, 0.2310, 0.1511], device='cuda:0')
# tensor([0.0200, 0.9800, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.9625033289194107
# Value Loss 0.045881513971835375
# Examples:
# tensor([0.1172, 0.2845, 0.2003, 0.3980], device='cuda:0')
# tensor([0.1300, 0.4300, 0.0000, 0.4400], device='cuda:0')
# 58/500
#
# Policy Loss 0.9408078193664551
# Value Loss 0.04075175803154707
# Examples:
# tensor([0.1097, 0.3157, 0.3739, 0.2007], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 0.946293443441391
# Value Loss 0.040322191547602415
# Examples:
# tensor([0.1078, 0.3186, 0.3754, 0.1983], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 59/500
#
# Policy Loss 0.9425217360258102
# Value Loss 0.04034014232456684
# Examples:
# tensor([0.1129, 0.2931, 0.1945, 0.3995], device='cuda:0')
# tensor([0.1300, 0.4300, 0.0000, 0.4400], device='cuda:0')
#
# Policy Loss 0.9326658844947815
# Value Loss 0.038345118053257465
# Examples:
# tensor([0.0615, 0.5913, 0.2183, 0.1289], device='cuda:0')
# tensor([0.0200, 0.9800, 0.0000, 0.0000], device='cuda:0')
# 60/500
#
# Policy Loss 1.3073817193508148
# Value Loss 0.03501603286713362
# Examples:
# tensor([0.0693, 0.3945, 0.3485, 0.1877], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
#
# Policy Loss 1.294998288154602
# Value Loss 0.03459301288239658
# Examples:
# tensor([0.1018, 0.3161, 0.3843, 0.1978], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 61/500
#
# Policy Loss 0.8937551230192184
# Value Loss 0.029521992430090904
# Examples:
# tensor([0.1086, 0.2960, 0.1844, 0.4110], device='cuda:0')
# tensor([0.1200, 0.4300, 0.0000, 0.4500], device='cuda:0')
#
# Policy Loss 0.9036793261766434
# Value Loss 0.030396674061194062
# Examples:
# tensor([0.0570, 0.5960, 0.2174, 0.1296], device='cuda:0')
# tensor([0.0200, 0.9800, 0.0000, 0.0000], device='cuda:0')
# 62/500
#
# Policy Loss 0.8946784883737564
# Value Loss 0.02858211612328887
# Examples:
# tensor([0.1068, 0.3013, 0.1800, 0.4119], device='cuda:0')
# tensor([0.1200, 0.4300, 0.0000, 0.4500], device='cuda:0')
#
# Policy Loss 0.8926278799772263
# Value Loss 0.028669389663264155
# Examples:
# tensor([0.0522, 0.6161, 0.2110, 0.1208], device='cuda:0')
# tensor([0.0200, 0.9800, 0.0000, 0.0000], device='cuda:0')
# 63/500
#
# Policy Loss 0.8887453526258469
# Value Loss 0.02693138737231493
# Examples:
# tensor([0.0496, 0.6246, 0.2096, 0.1162], device='cuda:0')
# tensor([0.0200, 0.9800, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.8846349641680717
# Value Loss 0.02602642262354493
# Examples:
# tensor([0.0908, 0.3292, 0.3964, 0.1836], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 64/500
#
# Policy Loss 0.8657524734735489
# Value Loss 0.022537406999617815
# Examples:
# tensor([0.1028, 0.3110, 0.1723, 0.4139], device='cuda:0')
# tensor([0.1100, 0.4400, 0.0000, 0.4500], device='cuda:0')
#
# Policy Loss 0.8634388372302055
# Value Loss 0.022167670773342252
# Examples:
# tensor([0.1019, 0.3139, 0.1695, 0.4147], device='cuda:0')
# tensor([0.1100, 0.4400, 0.0000, 0.4500], device='cuda:0')
# 65/500
#
# Policy Loss 0.825343668460846
# Value Loss 0.020335307344794273
# Examples:
# tensor([0.1009, 0.3166, 0.1677, 0.4148], device='cuda:0')
# tensor([0.1100, 0.4400, 0.0000, 0.4500], device='cuda:0')
#
# Policy Loss 0.8185189366340637
# Value Loss 0.01953367900568992
# Examples:
# tensor([0.1000, 0.3193, 0.1648, 0.4159], device='cuda:0')
# tensor([0.1100, 0.4400, 0.0000, 0.4500], device='cuda:0')
# 66/500
#
# Policy Loss 1.3846348822116852
# Value Loss 0.016436856472864747
# Examples:
# tensor([0.0831, 0.3372, 0.4037, 0.1759], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 1.3449247032403946
# Value Loss 0.018009663908742368
# Examples:
# tensor([0.0985, 0.3174, 0.1582, 0.4259], device='cuda:0')
# tensor([0.1000, 0.4500, 0.0000, 0.4500], device='cuda:0')
# 67/500
#
# Policy Loss 0.8449588119983673
# Value Loss 0.019462269730865955
# Examples:
# tensor([0.0814, 0.3330, 0.4078, 0.1778], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 0.8229908123612404
# Value Loss 0.018087785225361586
# Examples:
# tensor([0.0797, 0.3343, 0.4111, 0.1749], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 68/500
#
# Policy Loss 1.2686796486377716
# Value Loss 0.017400254029780626
# Examples:
# tensor([0.0960, 0.3208, 0.1500, 0.4332], device='cuda:0')
# tensor([0.1000, 0.4500, 0.0000, 0.4500], device='cuda:0')
#
# Policy Loss 1.280137687921524
# Value Loss 0.016520052449777722
# Examples:
# tensor([0.0475, 0.4251, 0.3610, 0.1664], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
# 69/500
#
# Policy Loss 0.8110675364732742
# Value Loss 0.014400646090507507
# Examples:
# tensor([0.0776, 0.3278, 0.4164, 0.1783], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 0.8065368831157684
# Value Loss 0.014713959069922566
# Examples:
# tensor([0.0761, 0.3308, 0.4174, 0.1757], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 70/500
#
# Policy Loss 0.794354036450386
# Value Loss 0.013606899417936802
# Examples:
# tensor([0.0930, 0.3276, 0.1397, 0.4397], device='cuda:0')
# tensor([0.1000, 0.4400, 0.0000, 0.4600], device='cuda:0')
#
# Policy Loss 0.7832330018281937
# Value Loss 0.013282762956805527
# Examples:
# tensor([0.0297, 0.7048, 0.1768, 0.0887], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 71/500
#
# Policy Loss 0.7949235439300537
# Value Loss 0.012927677715197206
# Examples:
# tensor([0.0713, 0.3374, 0.4235, 0.1678], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 0.7876050174236298
# Value Loss 0.012101251282729208
# Examples:
# tensor([0.0697, 0.3380, 0.4270, 0.1653], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 72/500
#
# Policy Loss 0.7551259696483612
# Value Loss 0.011678096372634172
# Examples:
# tensor([0.0877, 0.3377, 0.1326, 0.4419], device='cuda:0')
# tensor([0.0900, 0.4500, 0.0000, 0.4600], device='cuda:0')
#
# Policy Loss 0.776802621781826
# Value Loss 0.01185955898836255
# Examples:
# tensor([0.0237, 0.7368, 0.1653, 0.0742], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 73/500
#
# Policy Loss 0.7612814754247665
# Value Loss 0.010130841750651598
# Examples:
# tensor([0.0223, 0.7443, 0.1626, 0.0707], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.7520229369401932
# Value Loss 0.010458583594299853
# Examples:
# tensor([0.0210, 0.7517, 0.1598, 0.0675], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 74/500
#
# Policy Loss 1.2823249697685242
# Value Loss 0.010110754752531648
# Examples:
# tensor([0.0829, 0.3439, 0.1246, 0.4486], device='cuda:0')
# tensor([0.0800, 0.4600, 0.0000, 0.4600], device='cuda:0')
#
# Policy Loss 1.2928550243377686
# Value Loss 0.009933492285199463
# Examples:
# tensor([0.0808, 0.3427, 0.1216, 0.4549], device='cuda:0')
# tensor([0.0800, 0.4600, 0.0000, 0.4600], device='cuda:0')
# 75/500
#
# Policy Loss 0.7522249966859818
# Value Loss 0.008786334423348308
# Examples:
# tensor([0.0790, 0.3447, 0.1199, 0.4564], device='cuda:0')
# tensor([0.0800, 0.4500, 0.0000, 0.4700], device='cuda:0')
#
# Policy Loss 0.7403118312358856
# Value Loss 0.009039435419254005
# Examples:
# tensor([0.0780, 0.3476, 0.1179, 0.4565], device='cuda:0')
# tensor([0.0800, 0.4500, 0.0000, 0.4700], device='cuda:0')
# 76/500
#
# Policy Loss 0.6785018593072891
# Value Loss 0.0076167520601302385
# Examples:
# tensor([0.0586, 0.3284, 0.4607, 0.1523], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 0.7126375436782837
# Value Loss 0.008055300160776824
# Examples:
# tensor([0.0573, 0.3287, 0.4643, 0.1498], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 77/500
#
# Policy Loss 0.7199566811323166
# Value Loss 0.007442971924319863
# Examples:
# tensor([0.0560, 0.3287, 0.4680, 0.1473], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 0.7134718671441078
# Value Loss 0.007418923545628786
# Examples:
# tensor([0.0547, 0.3286, 0.4717, 0.1450], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 78/500
#
# Policy Loss 0.6404498964548111
# Value Loss 0.00693381845485419
# Examples:
# tensor([0.0534, 0.3266, 0.4775, 0.1426], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 0.6542700827121735
# Value Loss 0.006832879036664963
# Examples:
# tensor([0.0705, 0.3594, 0.1069, 0.4631], device='cuda:0')
# tensor([0.0700, 0.4400, 0.0000, 0.4900], device='cuda:0')
# 79/500
#
# Policy Loss 0.70414137840271
# Value Loss 0.00658087944611907
# Examples:
# tensor([0.0128, 0.7994, 0.1389, 0.0489], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.6961754411458969
# Value Loss 0.006364798580761999
# Examples:
# tensor([0.0120, 0.8045, 0.1368, 0.0467], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 80/500
#
# Policy Loss 0.6891729384660721
# Value Loss 0.005825472646392882
# Examples:
# tensor([0.0113, 0.8105, 0.1338, 0.0444], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.6715718135237694
# Value Loss 0.005883413017727435
# Examples:
# tensor([0.0672, 0.3613, 0.0983, 0.4732], device='cuda:0')
# tensor([0.0700, 0.4000, 0.0000, 0.5300], device='cuda:0')
# 81/500
#
# Policy Loss 0.6706793159246445
# Value Loss 0.0052524436032399535
# Examples:
# tensor([0.0100, 0.8203, 0.1292, 0.0405], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.6656790226697922
# Value Loss 0.005129312979988754
# Examples:
# tensor([0.0660, 0.3612, 0.0944, 0.4784], device='cuda:0')
# tensor([0.0700, 0.4000, 0.0000, 0.5300], device='cuda:0')
# 82/500
#
# Policy Loss 0.6280509978532791
# Value Loss 0.00464550667675212
# Examples:
# tensor([0.0444, 0.3053, 0.5244, 0.1259], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 0.626600094139576
# Value Loss 0.00447120048920624
# Examples:
# tensor([0.0083, 0.8342, 0.1223, 0.0352], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 83/500
#
# Policy Loss 0.6332758367061615
# Value Loss 0.004539271350950003
# Examples:
# tensor([0.0078, 0.8376, 0.1209, 0.0337], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.6375384852290154
# Value Loss 0.004558043961878866
# Examples:
# tensor([0.0415, 0.2965, 0.5420, 0.1201], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 84/500
#
# Policy Loss 0.6062973737716675
# Value Loss 0.004070664173923433
# Examples:
# tensor([0.0405, 0.2925, 0.5492, 0.1179], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
#
# Policy Loss 0.6250223517417908
# Value Loss 0.0041819948819465935
# Examples:
# tensor([0.0627, 0.3620, 0.0827, 0.4926], device='cuda:0')
# tensor([0.0700, 0.4000, 0.0000, 0.5300], device='cuda:0')
# 85/500
#
# Policy Loss 0.6121693551540375
# Value Loss 0.003948097059037536
# Examples:
# tensor([0.0614, 0.3621, 0.0811, 0.4954], device='cuda:0')
# tensor([0.0600, 0.4000, 0.0000, 0.5400], device='cuda:0')
#
# Policy Loss 0.6047257855534554
# Value Loss 0.00382388528669253
# Examples:
# tensor([0.0059, 0.8565, 0.1105, 0.0270], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 86/500
# Policy Loss 0.5906958281993866
# Value Loss 0.0033229757682420313
# Examples:
# tensor([0.0591, 0.3616, 0.0776, 0.5017], device='cuda:0')
# tensor([0.0600, 0.3900, 0.0000, 0.5500], device='cuda:0')
#
# Policy Loss 0.5798753648996353
# Value Loss 0.0033900798007380217
# Examples:
# tensor([0.0358, 0.2723, 0.5837, 0.1081], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 87/500
#
# Policy Loss 0.5913925766944885
# Value Loss 0.0035384841030463576
# Examples:
# tensor([0.0050, 0.8672, 0.1042, 0.0236], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.5802256762981415
# Value Loss 0.003283182595623657
# Examples:
# tensor([0.0342, 0.2621, 0.5994, 0.1043], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9700, 0.0100], device='cuda:0')
# 88/500
#
# Policy Loss 0.5414046496152878
# Value Loss 0.003058533649891615
# Examples:
# tensor([0.0046, 0.8748, 0.0991, 0.0215], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.5326973311603069
# Value Loss 0.0028370714862830937
# Examples:
# tensor([0.0562, 0.3597, 0.0694, 0.5148], device='cuda:0')
# tensor([0.0600, 0.3900, 0.0000, 0.5500], device='cuda:0')
# 89/500
#
# Policy Loss 0.5514032691717148
# Value Loss 0.002581190608907491
# Examples:
# tensor([0.0557, 0.3596, 0.0681, 0.5166], device='cuda:0')
# tensor([0.0600, 0.3900, 0.0000, 0.5500], device='cuda:0')
#
# Policy Loss 0.5511213541030884
# Value Loss 0.0026110437465831637
# Examples:
# tensor([0.0041, 0.8865, 0.0908, 0.0186], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 90/500
#
# Policy Loss 0.5646912902593613
# Value Loss 0.0026240417500957847
# Examples:
# tensor([0.0306, 0.2399, 0.6350, 0.0945], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9800, 0.0000], device='cuda:0')
#
# Policy Loss 0.537412241101265
# Value Loss 0.0025896939623635262
# Examples:
# tensor([0.0300, 0.2340, 0.6435, 0.0926], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9800, 0.0000], device='cuda:0')
# 91/500
#
# Policy Loss 0.5258054882287979
# Value Loss 0.0025659558014012873
# Examples:
# tensor([0.0292, 0.2279, 0.6525, 0.0904], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9800, 0.0000], device='cuda:0')
#
# Policy Loss 0.5283383280038834
# Value Loss 0.0023235018888954073
# Examples:
# tensor([0.0037, 0.8960, 0.0846, 0.0156], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 92/500
#
# Policy Loss 0.4935236796736717
# Value Loss 0.0024180777254514396
# Examples:
# tensor([0.0278, 0.2174, 0.6681, 0.0867], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9800, 0.0000], device='cuda:0')
#
# Policy Loss 0.4983431436121464
# Value Loss 0.002260997920529917
# Examples:
# tensor([0.0272, 0.2121, 0.6759, 0.0848], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9800, 0.0000], device='cuda:0')
# 93/500
#
# Policy Loss 0.49856045842170715
# Value Loss 0.002077713899780065
# Examples:
# tensor([0.0034, 0.9041, 0.0789, 0.0136], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.4905702732503414
# Value Loss 0.002100283920299262
# Examples:
# tensor([0.0259, 0.2016, 0.6914, 0.0811], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9800, 0.0000], device='cuda:0')
# 94/500
#
# Policy Loss 0.4786093682050705
# Value Loss 0.0019409046217333525
# Examples:
# tensor([0.0253, 0.1967, 0.6989, 0.0791], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9800, 0.0000], device='cuda:0')
#
# Policy Loss 0.4781031385064125
# Value Loss 0.0018904176104115322
# Examples:
# tensor([0.0460, 0.3544, 0.0511, 0.5484], device='cuda:0')
# tensor([0.0500, 0.3700, 0.0000, 0.5800], device='cuda:0')
# 95/500
#
# Policy Loss 0.4817528650164604
# Value Loss 0.0016338704735971987
# Examples:
# tensor([0.0031, 0.9159, 0.0698, 0.0112], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.47562943398952484
# Value Loss 0.0017476992652518675
# Examples:
# tensor([0.0233, 0.1819, 0.7213, 0.0736], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9800, 0.0000], device='cuda:0')
# 96/500
#
# Policy Loss 0.46891339123249054
# Value Loss 0.0014861294475849718
# Examples:
# tensor([0.0227, 0.1779, 0.7276, 0.0718], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9800, 0.0000], device='cuda:0')
#
# Policy Loss 0.4506637156009674
# Value Loss 0.001500771424616687
# Examples:
# tensor([0.0029, 0.9236, 0.0638, 0.0097], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 97/500
#
# Policy Loss 0.4300231784582138
# Value Loss 0.0015369123429991305
# Examples:
# tensor([0.0029, 0.9257, 0.0622, 0.0093], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.4435424394905567
# Value Loss 0.001404782582540065
# Examples:
# tensor([0.0391, 0.3515, 0.0437, 0.5658], device='cuda:0')
# tensor([0.0400, 0.3700, 0.0000, 0.5900], device='cuda:0')
# 98/500
#
# Policy Loss 0.4136371985077858
# Value Loss 0.0013413908891379833
# Examples:
# tensor([0.0028, 0.9305, 0.0583, 0.0084], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.42784498259425163
# Value Loss 0.0013164351257728413
# Examples:
# tensor([0.0383, 0.3502, 0.0420, 0.5695], device='cuda:0')
# tensor([0.0400, 0.3700, 0.0000, 0.5900], device='cuda:0')
# 99/500
#
# Policy Loss 0.4335876628756523
# Value Loss 0.0012861096183769405
# Examples:
# tensor([0.0379, 0.3490, 0.0406, 0.5726], device='cuda:0')
# tensor([0.0400, 0.3600, 0.0000, 0.6000], device='cuda:0')
#
# Policy Loss 0.42275624349713326
# Value Loss 0.0012276680645300075
# Examples:
# tensor([0.0026, 0.9358, 0.0542, 0.0073], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 100/500
#
# Policy Loss 0.38879913091659546
# Value Loss 0.0012009624770144
# Examples:
# tensor([0.0026, 0.9374, 0.0530, 0.0070], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.4006507284939289
# Value Loss 0.0011526304951985367
# Examples:
# tensor([0.0026, 0.9396, 0.0511, 0.0067], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 101/500
#
# Policy Loss 0.3950866162776947
# Value Loss 0.0010906426177825779
# Examples:
# tensor([0.0025, 0.9414, 0.0497, 0.0064], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.3868888132274151
# Value Loss 0.0010498898263904266
# Examples:
# tensor([0.0164, 0.1219, 0.8091, 0.0526], device='cuda:0')
# tensor([0.0100, 0.0100, 0.9800, 0.0000], device='cuda:0')
# 102/500
#
# Policy Loss 0.38599322736263275
# Value Loss 0.0009794122743187472
# Examples:
# tensor([0.0322, 0.3439, 0.0344, 0.5894], device='cuda:0')
# tensor([0.0300, 0.3600, 0.0000, 0.6100], device='cuda:0')
#
# Policy Loss 0.3885505050420761
# Value Loss 0.0009419368070666678
# Examples:
# tensor([0.0024, 0.9473, 0.0447, 0.0055], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 103/500
#
# Policy Loss 0.40120770037174225
# Value Loss 0.0008574638341087848
# Examples:
# tensor([0.0305, 0.3421, 0.0322, 0.5951], device='cuda:0')
# tensor([0.0300, 0.3500, 0.0000, 0.6200], device='cuda:0')
#
# Policy Loss 0.40015076473355293
# Value Loss 0.0008664344495628029
# Examples:
# tensor([0.0024, 0.9510, 0.0416, 0.0050], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 104/500
#
# Policy Loss 0.34783418476581573
# Value Loss 0.0008653428521938622
# Examples:
# tensor([0.0296, 0.3400, 0.0302, 0.6002], device='cuda:0')
# tensor([0.0300, 0.3500, 0.0000, 0.6200], device='cuda:0')
#
# Policy Loss 0.3607281818985939
# Value Loss 0.000824284041300416
# Examples:
# tensor([0.0140, 0.0961, 0.8464, 0.0435], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 105/500
#
# Policy Loss 0.3692512884736061
# Value Loss 0.0007639656105311587
# Examples:
# tensor([0.0024, 0.9556, 0.0376, 0.0043], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.3678363561630249
# Value Loss 0.0007541630839114077
# Examples:
# tensor([0.0130, 0.0880, 0.8584, 0.0406], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 106/500
#
# Policy Loss 0.37116456031799316
# Value Loss 0.0007296146068256348
# Examples:
# tensor([0.0125, 0.0843, 0.8641, 0.0391], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 0.3787735477089882
# Value Loss 0.0007142647373257205
# Examples:
# tensor([0.0121, 0.0816, 0.8686, 0.0378], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 107/500
# Policy Loss 0.35867326706647873
# Value Loss 0.0006018265994498506
# Examples:
# tensor([0.0117, 0.0790, 0.8728, 0.0364], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 0.35350507870316505
# Value Loss 0.000663402744976338
# Examples:
# tensor([0.0255, 0.3829, 0.0263, 0.5654], device='cuda:0')
# tensor([0.0200, 0.4400, 0.0000, 0.5400], device='cuda:0')
# 108/500
#
# Policy Loss 0.3554718494415283
# Value Loss 0.0006608959229197353
# Examples:
# tensor([0.0249, 0.3926, 0.0258, 0.5567], device='cuda:0')
# tensor([0.0200, 0.4500, 0.0000, 0.5300], device='cuda:0')
#
# Policy Loss 0.3397469334304333
# Value Loss 0.0006371914714691229
# Examples:
# tensor([0.0022, 0.9666, 0.0283, 0.0030], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 109/500
#
# Policy Loss 0.37506968528032303
# Value Loss 0.0006533311534440145
# Examples:
# tensor([0.0102, 0.0674, 0.8912, 0.0312], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 0.35478632897138596
# Value Loss 0.0006210006977198645
# Examples:
# tensor([0.0021, 0.9691, 0.0261, 0.0026], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 110/500
#
# Policy Loss 1.617226094007492
# Value Loss 0.0005672012193826959
# Examples:
# tensor([0.0069, 0.3484, 0.6226, 0.0221], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
#
# Policy Loss 1.591718852519989
# Value Loss 0.000606836547376588
# Examples:
# tensor([0.0076, 0.3462, 0.6223, 0.0239], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
# 111/500
#
# Policy Loss 1.8518643975257874
# Value Loss 0.0005184627952985466
# Examples:
# tensor([0.0111, 0.0628, 0.8928, 0.0332], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 1.6903038024902344
# Value Loss 0.000580578955123201
# Examples:
# tensor([0.0090, 0.3417, 0.6216, 0.0278], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
# 112/500
#
# Policy Loss 1.4670641422271729
# Value Loss 0.0006607012255699374
# Examples:
# tensor([0.0120, 0.0614, 0.8912, 0.0354], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 1.527386114001274
# Value Loss 0.0006750914581061807
# Examples:
# tensor([0.0124, 0.0606, 0.8904, 0.0366], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 113/500
#
# Policy Loss 1.5744838416576385
# Value Loss 0.0007505252724513412
# Examples:
# tensor([0.0116, 0.3395, 0.6144, 0.0345], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
#
# Policy Loss 1.531331405043602
# Value Loss 0.0007014478178462014
# Examples:
# tensor([0.0221, 0.4409, 0.0175, 0.5195], device='cuda:0')
# tensor([0.0200, 0.5000, 0.0000, 0.4800], device='cuda:0')
# 114/500
#
# Policy Loss 1.4138156175613403
# Value Loss 0.0008478103845845908
# Examples:
# tensor([0.0136, 0.3416, 0.6051, 0.0396], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
#
# Policy Loss 1.40794076025486
# Value Loss 0.0008077829770627432
# Examples:
# tensor([0.0218, 0.4452, 0.0165, 0.5166], device='cuda:0')
# tensor([0.0200, 0.5000, 0.0000, 0.4800], device='cuda:0')
# 115/500
#
# Policy Loss 1.232777178287506
# Value Loss 0.0009607769025024027
# Examples:
# tensor([0.0159, 0.3422, 0.5967, 0.0452], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
#
# Policy Loss 1.3150226026773453
# Value Loss 0.0009447870179428719
# Examples:
# tensor([0.0152, 0.0568, 0.8837, 0.0443], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 116/500
#
# Policy Loss 1.2671869993209839
# Value Loss 0.001001861717668362
# Examples:
# tensor([0.0155, 0.0564, 0.8824, 0.0457], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 1.2704915702342987
# Value Loss 0.0010391810865257867
# Examples:
# tensor([0.0157, 0.0560, 0.8812, 0.0471], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 117/500
#
# Policy Loss 1.4188920557498932
# Value Loss 0.0009438682754989713
# Examples:
# tensor([0.0160, 0.0557, 0.8797, 0.0486], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 1.3579437881708145
# Value Loss 0.0009805652152863331
# Examples:
# tensor([0.0162, 0.0552, 0.8787, 0.0499], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 118/500
#
# Policy Loss 1.3263903856277466
# Value Loss 0.0009500300657236949
# Examples:
# tensor([0.0184, 0.4580, 0.0130, 0.5106], device='cuda:0')
# tensor([0.0100, 0.5300, 0.0000, 0.4600], device='cuda:0')
#
# Policy Loss 1.3171295821666718
# Value Loss 0.0010021161870099604
# Examples:
# tensor([0.0167, 0.0547, 0.8759, 0.0527], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 119/500
#
# Policy Loss 1.2606710195541382
# Value Loss 0.000919242826057598
# Examples:
# tensor([0.0174, 0.4622, 0.0122, 0.5081], device='cuda:0')
# tensor([0.0100, 0.5300, 0.0000, 0.4600], device='cuda:0')
#
# Policy Loss 1.244994431734085
# Value Loss 0.0009618104304536246
# Examples:
# tensor([0.0268, 0.3611, 0.5346, 0.0775], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
# 120/500
#
# Policy Loss 1.0110944509506226
# Value Loss 0.0012633259466383606
# Examples:
# tensor([0.0278, 0.3600, 0.5305, 0.0818], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
#
# Policy Loss 1.0346199125051498
# Value Loss 0.001211012109706644
# Examples:
# tensor([0.0286, 0.3578, 0.5274, 0.0863], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
# 121/500
#
# Policy Loss 1.1391912996768951
# Value Loss 0.0010400487954029813
# Examples:
# tensor([0.0165, 0.0527, 0.8713, 0.0595], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 1.1233737617731094
# Value Loss 0.0009997432644013315
# Examples:
# tensor([0.0163, 0.0520, 0.8708, 0.0608], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 122/500
#
# Policy Loss 1.2105613946914673
# Value Loss 0.0008705952350283042
# Examples:
# tensor([0.0162, 0.0515, 0.8701, 0.0622], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 1.1575168371200562
# Value Loss 0.0008829456783132628
# Examples:
# tensor([0.0310, 0.3488, 0.5144, 0.1059], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
# 123/500
#
# Policy Loss 1.0458958595991135
# Value Loss 0.0008795182220637798
# Examples:
# tensor([0.0313, 0.3447, 0.5128, 0.1113], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
#
# Policy Loss 1.0266886353492737
# Value Loss 0.0009086924546863884
# Examples:
# tensor([0.0315, 0.3403, 0.5113, 0.1169], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
# 124/500
#
# Policy Loss 1.1704015135765076
# Value Loss 0.0007797575817676261
# Examples:
# tensor([0.0128, 0.4758, 0.0091, 0.5023], device='cuda:0')
# tensor([0.0100, 0.5300, 0.0000, 0.4600], device='cuda:0')
#
# Policy Loss 1.0993062034249306
# Value Loss 0.0008517418827977963
# Examples:
# tensor([0.0321, 0.3337, 0.5056, 0.1287], device='cuda:0')
# tensor([0.0300, 0.0000, 0.0000, 0.9700], device='cuda:0')
# 125/500
#
# Policy Loss 0.9036706387996674
# Value Loss 0.0009530996903777122
# Examples:
# tensor([0.0119, 0.4785, 0.0086, 0.5010], device='cuda:0')
# ...
# tensor([0.0100, 0.5000, 0.0000, 0.4900], device='cuda:0')
#
# Policy Loss 0.3030960150063038
# Value Loss 2.1008893930085648e-10
# Examples:
# tensor([2.9725e-02, 1.9106e-02, 6.2991e-07, 9.5117e-01], device='cuda:0')
# tensor([0.0200, 0.0000, 0.0000, 0.9800], device='cuda:0')
# 464/500
#
# Policy Loss 0.34613536298274994
# Value Loss 1.5986144352719833e-10
# Examples:
# tensor([9.7100e-03, 5.0021e-01, 1.2040e-08, 4.9008e-01], device='cuda:0')
# tensor([0.0100, 0.5000, 0.0000, 0.4900], device='cuda:0')
#
# Policy Loss 0.30968114361166954
# Value Loss 1.6654246731695466e-10
# Examples:
# tensor([9.7969e-03, 5.0200e-01, 1.1859e-08, 4.8821e-01], device='cuda:0')
# tensor([0.0100, 0.5000, 0.0000, 0.4900], device='cuda:0')
# 465/500
#
# Policy Loss 0.27938224002718925
# Value Loss 1.572916380476741e-10
# Examples:
# tensor([2.1866e-02, 1.1971e-02, 5.3170e-07, 9.6616e-01], device='cuda:0')
# tensor([0.0200, 0.0000, 0.0000, 0.9800], device='cuda:0')
#
# Policy Loss 0.29528864100575447
# Value Loss 1.4862510527846595e-10
# Examples:
# tensor([1.9928e-02, 1.0227e-02, 5.1276e-07, 9.6984e-01], device='cuda:0')
# tensor([0.0200, 0.0000, 0.0000, 0.9800], device='cuda:0')
# 466/500
#
# Policy Loss 0.3033967465162277
# Value Loss 1.1056465465397736e-10
# Examples:
# tensor([9.6450e-03, 1.9755e-05, 9.9007e-01, 2.6713e-04], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 0.29783890023827553
# Value Loss 1.1858863196989589e-10
# Examples:
# tensor([1.9708e-02, 7.4624e-03, 5.5654e-07, 9.7283e-01], device='cuda:0')
# tensor([0.0200, 0.0000, 0.0000, 0.9800], device='cuda:0')
# 467/500
#
# Policy Loss 0.32927305996418
# Value Loss 1.2084000466927591e-10
# Examples:
# tensor([9.7709e-03, 1.8353e-05, 9.8995e-01, 2.6178e-04], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 0.3090939149260521
# Value Loss 1.1857811260673756e-10
# Examples:
# tensor([1.9816e-02, 5.4447e-03, 6.0727e-07, 9.7474e-01], device='cuda:0')
# tensor([0.0200, 0.0000, 0.0000, 0.9800], device='cuda:0')
# 468/500
#
# Policy Loss 0.24795686453580856
# Value Loss 1.1039008596114286e-10
# Examples:
# tensor([9.7180e-03, 1.6529e-05, 9.9001e-01, 2.5296e-04], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 0.2788919694721699
# Value Loss 1.0053234633655705e-10
# Examples:
# tensor([9.7326e-03, 1.5786e-05, 9.9000e-01, 2.4872e-04], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 469/500
#
# Policy Loss 0.31122931092977524
# Value Loss 7.528283552105108e-11
# Examples:
# tensor([9.8166e-03, 1.5344e-05, 9.8992e-01, 2.4694e-04], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 0.3260696269571781
# Value Loss 7.446624566975757e-11
# Examples:
# tensor([1.0144e-02, 4.9893e-01, 7.2717e-09, 4.9092e-01], device='cuda:0')
# tensor([0.0100, 0.5000, 0.0000, 0.4900], device='cuda:0')
# 470/500
#
# Policy Loss 0.2878810912370682
# Value Loss 8.05770311584908e-11
# Examples:
# tensor([1.9943e-02, 2.5148e-03, 6.6528e-07, 9.7754e-01], device='cuda:0')
# tensor([0.0200, 0.0000, 0.0000, 0.9800], device='cuda:0')
#
# Policy Loss 0.3113260790705681
# Value Loss 7.327605189288988e-11
# Examples:
# tensor([1.9991e-02, 2.1663e-03, 6.7612e-07, 9.7784e-01], device='cuda:0')
# tensor([0.0200, 0.0000, 0.0000, 0.9800], device='cuda:0')
# 471/500
#
# Policy Loss 0.3323499262332916
# Value Loss 5.872069497314669e-11
# Examples:
# tensor([1.9973e-02, 1.8756e-03, 6.7606e-07, 9.7815e-01], device='cuda:0')
# tensor([0.0200, 0.0000, 0.0000, 0.9800], device='cuda:0')
#
# Policy Loss 0.31112759187817574
# Value Loss 6.040035138710209e-11
# Examples:
# tensor([9.7291e-03, 1.2395e-05, 9.9003e-01, 2.2656e-04], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 472/500
#
# Policy Loss 0.28028906881809235
# Value Loss 5.4270532512390446e-11
# Examples:
# tensor([1.0208e-02, 4.9591e-01, 6.2173e-09, 4.9388e-01], device='cuda:0')
# tensor([0.0100, 0.5000, 0.0000, 0.4900], device='cuda:0')
#
# Policy Loss 0.28921210393309593
# Value Loss 5.125261326455188e-11
# Examples:
# tensor([9.9494e-03, 5.0190e-01, 5.7473e-09, 4.8815e-01], device='cuda:0')
# tensor([0.0100, 0.5000, 0.0000, 0.4900], device='cuda:0')
# 473/500
#
# Policy Loss 0.3077911101281643
# Value Loss 3.8337527596965515e-11
# Examples:
# tensor([1.9847e-02, 1.0477e-03, 7.0652e-07, 9.7910e-01], device='cuda:0')
# tensor([0.0200, 0.0000, 0.0000, 0.9800], device='cuda:0')
#
# Policy Loss 0.31010675244033337
# Value Loss 3.7480650527665915e-11
# Examples:
# tensor([1.9990e-02, 9.0641e-04, 7.2793e-07, 9.7910e-01], device='cuda:0')
# tensor([0.0200, 0.0000, 0.0000, 0.9800], device='cuda:0')
# 474/500
#
# Policy Loss 0.32126811146736145
# Value Loss 3.674356652272337e-11
# Examples:
# tensor([1.0207e-02, 4.9651e-01, 5.4887e-09, 4.9328e-01], device='cuda:0')
# tensor([0.0100, 0.5000, 0.0000, 0.4900], device='cuda:0')
#
# Policy Loss 0.31261709332466125
# Value Loss 3.4983752006390034e-11
# Examples:
# tensor([2.0056e-02, 6.8792e-04, 7.7700e-07, 9.7926e-01], device='cuda:0')
# tensor([0.0200, 0.0000, 0.0000, 0.9800], device='cuda:0')
# 475/500
#
# Policy Loss 0.26490621268749237
# Value Loss 3.330304088056124e-11
# Examples:
# tensor([1.0052e-02, 5.0181e-01, 5.0053e-09, 4.8814e-01], device='cuda:0')
# tensor([0.0100, 0.5000, 0.0000, 0.4900], device='cuda:0')
#
# Policy Loss 0.2890867181122303
# Value Loss 2.934035653323619e-11
# Examples:
# tensor([1.0133e-02, 4.9764e-01, 4.9951e-09, 4.9222e-01], device='cuda:0')
# tensor([0.0100, 0.5000, 0.0000, 0.4900], device='cuda:0')
# 476/500
#
# Policy Loss 0.31592558324337006
# Value Loss 2.3350821276579836e-11
# Examples:
# tensor([1.9965e-02, 4.5586e-04, 8.2879e-07, 9.7958e-01], device='cuda:0')
# tensor([0.0200, 0.0000, 0.0000, 0.9800], device='cuda:0')
#
# Policy Loss 0.30846988782286644
# Value Loss 2.454433184473359e-11
# Examples:
# tensor([2.0017e-02, 4.0207e-04, 8.4410e-07, 9.7958e-01], device='cuda:0')
# tensor([0.0200, 0.0000, 0.0000, 0.9800], device='cuda:0')
# 477/500
#
# Policy Loss 0.2890859767794609
# Value Loss 2.3021265449507666e-11
# Examples:
# tensor([9.8491e-03, 8.1111e-06, 9.8995e-01, 1.8861e-04], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 0.29746613651514053
# Value Loss 2.3139309912600936e-11
# Examples:
# tensor([2.0002e-02, 3.1015e-04, 8.8224e-07, 9.7969e-01], device='cuda:0')
# tensor([0.0200, 0.0000, 0.0000, 0.9800], device='cuda:0')
# 478/500
#
# Policy Loss 0.972663089632988
# Value Loss 2.6198959668377597e-11
# Examples:
# tensor([1.0371e-02, 4.8070e-01, 5.1448e-09, 5.0893e-01], device='cuda:0')
# tensor([0.0100, 0.4500, 0.0000, 0.5400], device='cuda:0')
#
# Policy Loss 0.9233942627906799
# Value Loss 2.979467367270061e-11
# Examples:
# tensor([2.3568e-02, 1.5132e-01, 6.1033e-12, 8.2512e-01], device='cuda:0')
# tensor([0.0200, 0.9800, 0.0000, 0.0000], device='cuda:0')
# 479/500
#
# Policy Loss 0.8176810443401337
# Value Loss 3.956840410879181e-11
# Examples:
# tensor([9.9954e-03, 4.6070e-01, 5.4958e-09, 5.2930e-01], device='cuda:0')
# tensor([0.0100, 0.4600, 0.0000, 0.5300], device='cuda:0')
#
# Policy Loss 0.822164423763752
# Value Loss 4.240089529483626e-11
# Examples:
# tensor([2.3132e-02, 2.0931e-01, 5.9174e-12, 7.6756e-01], device='cuda:0')
# tensor([0.0200, 0.9800, 0.0000, 0.0000], device='cuda:0')
# 480/500
#
# Policy Loss 0.7227753698825836
# Value Loss 5.870511021743852e-11
# Examples:
# tensor([1.0061e-02, 4.6592e-01, 5.6186e-09, 5.2402e-01], device='cuda:0')
# tensor([0.0100, 0.4600, 0.0000, 0.5300], device='cuda:0')
#
# Policy Loss 0.7000811696052551
# Value Loss 5.898894567257784e-11
# Examples:
# tensor([1.0264e-02, 4.6068e-01, 6.2131e-09, 5.2906e-01], device='cuda:0')
# tensor([0.0100, 0.4600, 0.0000, 0.5300], device='cuda:0')
# 481/500
#
# Policy Loss 0.7131358981132507
# Value Loss 5.842143435685898e-11
# Examples:
# tensor([1.0085e-02, 4.6626e-01, 6.3406e-09, 5.2365e-01], device='cuda:0')
# tensor([0.0100, 0.4600, 0.0000, 0.5300], device='cuda:0')
#
# Policy Loss 0.6624820530414581
# Value Loss 6.438731492419691e-11
# Examples:
# tensor([1.0350e-02, 4.5945e-01, 7.1707e-09, 5.3020e-01], device='cuda:0')
# tensor([0.0100, 0.4600, 0.0000, 0.5300], device='cuda:0')
# 482/500
#
# Policy Loss 0.610584169626236
# Value Loss 6.753231307499163e-11
# Examples:
# tensor([1.0056e-02, 4.6483e-01, 7.0845e-09, 5.2511e-01], device='cuda:0')
# tensor([0.0100, 0.4600, 0.0000, 0.5300], device='cuda:0')
#
# Policy Loss 0.5803443863987923
# Value Loss 7.301469845399922e-11
# Examples:
# tensor([9.8711e-03, 1.2071e-05, 9.8996e-01, 1.6137e-04], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 483/500
#
# Policy Loss 0.5369262248277664
# Value Loss 7.484125819079424e-11
# Examples:
# tensor([1.8774e-02, 4.9992e-01, 4.8537e-12, 4.8130e-01], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.5181553289294243
# Value Loss 7.835176257797727e-11
# Examples:
# tensor([9.8586e-03, 1.2752e-05, 9.8997e-01, 1.5868e-04], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 484/500
#
# Policy Loss 0.4814409837126732
# Value Loss 7.991957096109559e-11
# Examples:
# tensor([1.6863e-02, 5.8880e-01, 4.4992e-12, 3.9434e-01], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.46900083497166634
# Value Loss 8.271666684933621e-11
# Examples:
# tensor([9.9835e-03, 4.5978e-01, 8.0314e-09, 5.3023e-01], device='cuda:0')
# tensor([0.0100, 0.4600, 0.0000, 0.5300], device='cuda:0')
# 485/500
#
# Policy Loss 0.420749232172966
# Value Loss 9.069880957390808e-11
# Examples:
# tensor([1.4803e-02, 6.7059e-01, 4.0612e-12, 3.1461e-01], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.4075503796339035
# Value Loss 9.538012046839128e-11
# Examples:
# tensor([9.8957e-03, 1.3203e-05, 9.8994e-01, 1.4995e-04], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 486/500
#
# Policy Loss 0.4024240970611572
# Value Loss 9.290615499146782e-11
# Examples:
# tensor([1.0131e-02, 4.6107e-01, 8.3592e-09, 5.2880e-01], device='cuda:0')
# tensor([0.0100, 0.4600, 0.0000, 0.5300], device='cuda:0')
#
# Policy Loss 0.39618081226944923
# Value Loss 9.86093012800282e-11
# Examples:
# tensor([1.0085e-02, 4.5923e-01, 8.3708e-09, 5.3068e-01], device='cuda:0')
# tensor([0.0100, 0.4600, 0.0000, 0.5300], device='cuda:0')
# 487/500
#
# Policy Loss 0.3479268327355385
# Value Loss 1.1093805041273441e-10
# Examples:
# tensor([1.0728e-02, 8.0154e-01, 3.1202e-12, 1.8773e-01], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.3383880741894245
# Value Loss 1.1347145445483875e-10
# Examples:
# tensor([9.8221e-03, 8.2734e-01, 2.8907e-12, 1.6284e-01], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 488/500
#
# Policy Loss 0.33960798382759094
# Value Loss 1.0231802904936416e-10
# Examples:
# tensor([9.9025e-03, 1.3424e-05, 9.8995e-01, 1.3642e-04], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 0.3196210414171219
# Value Loss 1.1108227532252712e-10
# Examples:
# tensor([9.8752e-03, 1.3426e-05, 9.8998e-01, 1.3351e-04], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 489/500
#
# Policy Loss 0.3504221737384796
# Value Loss 1.1290576806821662e-10
# Examples:
# tensor([9.9626e-03, 1.3438e-05, 9.8989e-01, 1.3036e-04], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 0.3647933788597584
# Value Loss 1.0479394435547462e-10
# Examples:
# tensor([1.0167e-02, 4.5781e-01, 8.5531e-09, 5.3203e-01], device='cuda:0')
# tensor([0.0100, 0.4600, 0.0000, 0.5300], device='cuda:0')
# 490/500
#
# Policy Loss 0.31636978685855865
# Value Loss 1.124674381403068e-10
# Examples:
# tensor([8.8705e-03, 9.1326e-01, 1.7487e-12, 7.7873e-02], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.3225403465330601
# Value Loss 1.0888333290548502e-10
# Examples:
# tensor([8.6176e-03, 9.2483e-01, 1.4909e-12, 6.6554e-02], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 491/500
#
# Policy Loss 0.3132135346531868
# Value Loss 1.1718291614837284e-10
# Examples:
# tensor([8.3547e-03, 9.3495e-01, 1.2657e-12, 5.6692e-02], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.3163549602031708
# Value Loss 1.1244574021906928e-10
# Examples:
# tensor([1.0077e-02, 4.5824e-01, 8.5438e-09, 5.3168e-01], device='cuda:0')
# tensor([0.0100, 0.4600, 0.0000, 0.5300], device='cuda:0')
# 492/500
#
# Policy Loss 0.2888861149549484
# Value Loss 1.2994795517418112e-10
# Examples:
# tensor([9.9216e-03, 1.2936e-05, 9.8995e-01, 1.1139e-04], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 0.3082497827708721
# Value Loss 1.1851575276722315e-10
# Examples:
# tensor([1.0054e-02, 4.6006e-01, 8.5179e-09, 5.2988e-01], device='cuda:0')
# tensor([0.0100, 0.4600, 0.0000, 0.5300], device='cuda:0')
# 493/500
#
# Policy Loss 0.27017825096845627
# Value Loss 1.287839695995885e-10
# Examples:
# tensor([1.0043e-02, 4.6383e-01, 8.3534e-09, 5.2613e-01], device='cuda:0')
# tensor([0.0100, 0.4600, 0.0000, 0.5300], device='cuda:0')
#
# Policy Loss 0.2795855365693569
# Value Loss 1.1619009226970789e-10
# Examples:
# tensor([7.1803e-03, 9.6641e-01, 5.4805e-13, 2.6408e-02], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 494/500
#
# Policy Loss 0.311982624232769
# Value Loss 1.244593039739783e-10
# Examples:
# tensor([7.0356e-03, 9.6997e-01, 4.6627e-13, 2.2991e-02], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.3026236966252327
# Value Loss 1.216856476693451e-10
# Examples:
# tensor([6.8178e-03, 9.7323e-01, 3.8812e-13, 1.9956e-02], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 495/500
#
# Policy Loss 0.2997647896409035
# Value Loss 1.2481585209833668e-10
# Examples:
# tensor([9.8851e-03, 4.6439e-01, 8.1207e-09, 5.2573e-01], device='cuda:0')
# tensor([0.0100, 0.4600, 0.0000, 0.5300], device='cuda:0')
#
# Policy Loss 0.2994263879954815
# Value Loss 1.2419743705693875e-10
# Examples:
# tensor([6.4738e-03, 9.7850e-01, 2.7382e-13, 1.5023e-02], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
# 496/500
#
# Policy Loss 0.2693532630801201
# Value Loss 1.314448550004954e-10
# Examples:
# tensor([6.3131e-03, 9.8069e-01, 2.3184e-13, 1.3001e-02], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.2875286266207695
# Value Loss 1.2753509359697546e-10
# Examples:
# tensor([9.9164e-03, 1.2079e-05, 9.8998e-01, 8.7439e-05], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 497/500
#
# Policy Loss 0.30911868810653687
# Value Loss 1.2413685357426374e-10
# Examples:
# tensor([6.0232e-03, 9.8423e-01, 1.6712e-13, 9.7473e-03], device='cuda:0')
# tensor([0.0100, 0.9900, 0.0000, 0.0000], device='cuda:0')
#
# Policy Loss 0.2994711138308048
# Value Loss 1.3357660116897208e-10
# Examples:
# tensor([1.0038e-02, 5.0572e-01, 7.0501e-09, 4.8424e-01], device='cuda:0')
# tensor([0.0100, 0.4900, 0.0000, 0.5000], device='cuda:0')
# 498/500
#
# Policy Loss 0.38244426250457764
# Value Loss 1.354539674869315e-10
# Examples:
# tensor([9.9760e-03, 1.3066e-05, 9.8993e-01, 8.5250e-05], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 0.3777235969901085
# Value Loss 1.342276845228696e-10
# Examples:
# tensor([9.9237e-03, 1.3952e-05, 9.8997e-01, 9.0619e-05], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
# 499/500
#
# Policy Loss 0.3385566771030426
# Value Loss 1.4844821205617365e-10
# Examples:
# tensor([9.9054e-03, 1.4567e-05, 9.8998e-01, 9.7515e-05], device='cuda:0')
# tensor([0.0100, 0.0000, 0.9900, 0.0000], device='cuda:0')
#
# Policy Loss 0.32833894342184067
# Value Loss 1.5714499840280283e-10
# Examples:
# tensor([1.0949e-01, 3.4634e-02, 7.7078e-07, 8.5588e-01], device='cuda:0')
# tensor([0.0200, 0.0000, 0.0000, 0.9800], device='cuda:0')
# 500/500
# Policy Loss 0.3267146348953247
# Value Loss 1.4201653741885423e-10
# Examples:
# tensor([9.8153e-03, 5.4538e-01, 8.0640e-09, 4.4480e-01], device='cuda:0')
# tensor([0.0100, 0.5500, 0.0000, 0.4400], device='cuda:0')
#
# Policy Loss 0.3204425051808357
# Value Loss 1.4065287823328276e-10
# Examples:
# tensor([9.5000e-03, 5.5054e-01, 7.5843e-09, 4.3996e-01], device='cuda:0')
# tensor([0.0100, 0.5500, 0.0000, 0.4400], device='cuda:0')
